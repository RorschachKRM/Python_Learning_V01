# %% [markdown]
# # Python学习

# %% [markdown]
# # 常用快捷键

# %% [markdown]
# - 终端中运行python文件（自定义）：Shift + R
# - 选中整行: Ctrl + L
# - 按单词移动: Ctrl + ←/→
# - 移动到文件开头/结尾: Ctrl + Home / Ctrl + End
# - 删除当前行: Ctrl + Shift + K
# - 向上/下复制当前行: Shift + Alt + ↑/↓
# - 选中所有相同词: Ctrl + Shift + L
# - 跳转到定义: F12
# - 查看定义: Alt + F12
# - 重命名符号: F2
# - 转到指定行: Ctrl + G
# - 转到文件: Ctrl + P

# %% [markdown]
# # 不换行print

# %% [markdown]
# print 默认输出是换行的，如果要实现不换行需要在变量末尾加上 end=""

# %%
x="a"
y="b"

# 不换行输出
print( x, end=" " )
print( y, end=" " )

# %% [markdown]
# # 字符串

# %% [markdown]
# ## 字符串切片

# %% [markdown]
# - **str[start:end]，左闭右开**
# - 加上步长参数 step，语法格式如下：str[start:end:step]

# %%
str='123456789'
print(str)                 # 输出字符串
print(str[0:-1])           # 输出第一个到倒数第二个的所有字符
print(str[0])              # 输出字符串第一个字符
print(str[2:5])            # 输出从第三个开始到第六个的字符（不包含）
print(str[2:])             # 输出从第三个开始后的所有字符
print(str[1:5:2])          # 输出从第二个开始到第五个且每隔一个的字符（步长为2）
print(str * 2)             # 输出字符串两次

# %% [markdown]
# ## \r 转义符

# %% [markdown]
# 回车，将 \r 后面的内容移到字符串开头，并逐一替换开头部分的字符，直至将 \r 后面的内容完全替换完成。

# %%
import time

for i in range(101): # 添加进度条图形和百分比
    bar = '[' + '=' * (i // 2) + ' ' * (50 - i // 2) + ']'
    print(f"\r{bar} {i:3}%", end='', flush=True)
    time.sleep(0.05)
print()

# %% [markdown]
# ## f-string

# %% [markdown]
# 字面量格式化字符串
# - f-string 格式化字符串以 f 开头，后面跟着字符串，字符串中的表达式用大括号 {} 包起来，它会将变量或表达式计算后的值替换进去
# - 也可以使用 = 符号来拼接运算表达式与结果

# %%
name = 'Runoob'
print(f'Hello {name}')  # 替换变量


x = 1
print(f'{x+1}')   # Python 3.6
print(f'{x+1=}')   # Python 3.8

# %% [markdown]
# ## 字符串内建函数

# %% [markdown]
# ### 字符串实例方法
# （通过字符串对象直接调用，如 `"abc".upper()`）
#
# | 方法 | 描述 | 示例 |
# |---|---|---|
# | `capitalize()` | 将字符串的第一个字符转换为大写 | `"hello".capitalize()` → `"Hello"` |
# | `center()` | 返回一个指定宽度居中的字符串，可指定填充字符 | `"a".center(3, "-")` → `"-a-"` |
# | `count()` | 返回指定字符串在原字符串里出现的次数 | `"aba".count("a")` → `2` |
# | `encode()` | 以指定的编码格式编码字符串，返回 bytes 对象 | `"a".encode("utf-8")` → `b"a"` |
# | `endswith()` | 检查字符串是否以指定字符结束 | `"abc".endswith("c")` → `True` |
# | `expandtabs()` | 把字符串中的 tab 符号转为空格，默认空格数为 8 | `"a\tb".expandtabs(4)` → `"a   b"` |
# | `find()` | 检测是否包含子串，包含则返回开始的索引值，否则返回 -1 | `"abc".find("b")` → `1` |
# | `index()` | 跟 find() 一样，但如果子串不存在会报 ValueError | `"abc".index("b")` → `1` |
# | `isalnum()` | 检查字符串是否全由字母和数字组成 | `"a1".isalnum()` → `True` |
# | `isalpha()` | 检查字符串是否全部由字母或中文组成 | `"abc".isalpha()` → `True` |
# | `isdecimal()` | 检查字符串是否只包含十进制字符 | `"1".isdecimal()` → `True` |
# | `isdigit()` | 检查字符串是否只包含数字 | `"123".isdigit()` → `True` |
# | `islower()` | 包含至少一个区分大小写的字符且全是小写则返回 True | `"abc".islower()` → `True` |
# | `isnumeric()` | 检查字符串是否只包含数字字符 | `"123".isnumeric()` → `True` |
# | `isspace()` | 检查字符串是否只包含空白字符 | `" ".isspace()` → `True` |
# | `istitle()` | 检查字符串是否为标题化格式 | `"Hello World".istitle()` → `True` |
# | `isupper()` | 包含至少一个区分大小写的字符且全是大写则返回 True | `"ABC".isupper()` → `True` |
# | `join(seq)` | 以指定字符串作为分隔符，将序列中所有元素合并为新字符串 | `"-".join(["a", "b"])` → `"a-b"` |
# | `ljust()` | 返回左对齐并使用指定字符填充至指定长度的新字符串 | `"a".ljust(3, "*")` → `"a**"` |
# | `lower()` | 将字符串中所有大写字符转换为小写 | `"ABC".lower()` → `"abc"` |
# | `lstrip()` | 截掉字符串左侧的空格或指定字符 | `" a".lstrip()` → `"a"` |
# | `replace()` | 将字符串中的旧字符替换为新字符 | `"aba".replace("a", "c")` → `"cbc"` |
# | `rfind()` | 类似于 find()，但从右侧开始查找 | `"aba".rfind("a")` → `2` |
# | `rindex()` | 类似于 index()，但从右侧开始查找 | `"aba".rindex("a")` → `2` |
# | `rjust()` | 返回右对齐并使用指定字符填充至指定长度的新字符串 | `"a".rjust(3, "*")` → `"**a"` |
# | `rstrip()` | 删除字符串末尾的空格或指定字符 | `"a ".rstrip()` → `"a"` |
# | `split()` | 以指定字符为分隔符截取字符串，返回列表 | `"a,b".split(",")` → `["a", "b"]` |
# | `splitlines()` | 按照行分隔，返回包含各行作为元素的列表 | `"a\nb".splitlines()` → `["a", "b"]` |
# | `startswith()` | 检查字符串是否以指定子字符串开头 | `"abc".startswith("a")` → `True` |
# | `strip()` | 同时执行 lstrip() 和 rstrip()，去除两端字符 | `" a ".strip()` → `"a"` |
# | `swapcase()` | 将字符串中的大写转小写，小写转大写 | `"aB".swapcase()` → `"Ab"` |
# | `title()` | 返回标题化的字符串（每个单词首字母大写） | `"hello w".title()` → `"Hello W"` |
# | `translate()` | 根据映射表转换字符串的字符 | `"a".translate({97: 98})` → `"b"` |
# | `upper()` | 将字符串中的小写字母转换为大写 | `"a".upper()` → `"A"` |
# | `zfill()` | 返回指定长度的字符串，右对齐并在前面填充 0 | `"1".zfill(3)` → `"001"` |

# %% [markdown]
# ### 适用于字符串的内置函数
# （Python 内置函数，传入字符串作为参数）
#
# | 函数 | 描述 | 示例 |
# |---|---|---|
# | `len()` | 返回字符串长度 | `len("abc")` → `3` |
# | `max()` | 返回字符串中最大的字符（按 Unicode 码位） | `max("abc")` → `"c"` |
# | `min()` | 返回字符串中最小的字符（按 Unicode 码位） | `min("abc")` → `"a"` |

# %% [markdown]
# # import 与 from...import

# %% [markdown]
# 在 python 用 import 或者 from...import 来导入相应的模块。
#
# - 将整个模块导入，格式为： import somemodule
# - 从某个模块中导入某个函数,格式为： from somemodule import somefunction
# - 从某个模块中导入多个函数,格式为： from somemodule import firstfunc, secondfunc, thirdfunc
# - 将某个模块中的全部函数导入，格式为： from somemodule import *

# %% [markdown]
# # type() 函数、isinstance()函数

# %%
# 查看变量的类型
x = 10
print(type(x))

isinstance(x, int) # isinstance() 会认为子类是一种父类类型。
# bool 是 int 的子类，因此布尔值可以被看作整数来使用，其中 True 等价于 1，False 等价于 0。

# %% [markdown]
# # 数值的除法

# %%
#包含两个运算符：
print( 2 / 4)    # 除法，得到一个浮点数
print( 2 // 4)    # 整除，得到一个整数（向下取整）

# %% [markdown]
# # 复数
# 可以用 a + bj 或者 complex(a, b) 表示，复数的实部 a 和虚部 b 都是浮点型。

# %% [markdown]
# # bool() 函数
# - 将其他类型的值转换为布尔值。以下值转换为布尔值时为 False：None、False、零（0、0.0、0j）、空序列（如 ''、()、[]）和空映射（如 {}）。
# - 其他所有值转换为布尔值时均为 True。

# %%
print(bool(0))
print(bool(42))
print(bool(''))
print(bool('Python'))   
print(bool([]))         
print(bool([1, 2, 3]))

# %% [markdown]
# # 列表 []

# %% [markdown]
# - 列表写在方括号 [] 之间，用逗号分隔开的元素列表
# - 可以被索引和截取，列表被截取后返回一个包含所需元素的新列表
# - 列表截取可以接收第三个参数，参数作用是截取的步长，第三个参数为负数表示逆向读取
# - 列表中的元素是可以改变的

# %%
my_list = ['abcd', 786, 2.23, 'runoob', 70.2]
tinylist = [123, 'runoob']

print(my_list)
print(my_list[0])
print(my_list[1:3])
print(my_list[2:])
print(tinylist * 2)        
print(my_list + tinylist)  

a = [1, 2, 3, 4, 5, 6]
a[2:5] = [13, 14, 15]
print(a)
a[2:5] = [] 
print(a)

# %% [markdown]
# ## del删除列表元素

# %% [markdown]
# 使用 del 语句来删除列表中的元素

# %%
list = ['Google', 'Runoob', 1997, 2000]
print ("原始列表 : ", list)

del list[2]
print ("删除第三个元素 : ", list)

# %% [markdown]
# ## 列表比较

# %% [markdown]
# 需要引入 operator 模块的 eq 方法

# %%
# 导入 operator 模块
import operator

a = [1, 2]
b = [2, 3]
c = [2, 3]
print("operator.eq(a,b): ", operator.eq(a,b))
print("operator.eq(c,b): ", operator.eq(c,b))

# %% [markdown]
# ## 列表函数

# %% [markdown]
# （Python 内置函数，传入列表作为参数）
#
# | 函数 | 描述 | 示例 |
# |---|---|---|
# | `len(list)` | 返回列表元素个数 | `len([1, 2, 3])` → `3` |
# | `max(list)` | 返回列表元素中的最大值 | `max([1, 2, 3])` → `3` |
# | `min(list)` | 返回列表元素中的最小值 | `min([1, 2, 3])` → `1` |
# | `list(seq)` | 将元组（或其他可迭代对象）转换为列表 | `list((1, 2, 3))` → `[1, 2, 3]` |

# %% [markdown]
# ## 列表.方法

# %% [markdown]
# （通过列表对象直接调用，如 `[1, 2, 3].append(4)`）
#
# | 方法 | 描述 | 示例 |
# |---|---|---|
# | `append(obj)` | 在列表末尾添加新的对象 | `[1, 2].append(3)` → `[1, 2, 3]` |
# | `count(obj)` | 统计某个元素在列表中出现的次数 | `[1, 2, 1].count(1)` → `2` |
# | `extend(seq)` | 在列表末尾一次性追加另一个序列中的多个值 | `[1, 2].extend([3, 4])` → `[1, 2, 3, 4]` |
# | `index(obj)` | 找出某个值第一个匹配项的索引位置 | `[1, 2, 3].index(2)` → `1` |
# | `insert(index, obj)` | 将对象插入到列表的指定位置 | `[1, 3].insert(1, 2)` → `[1, 2, 3]` |
# | `pop([index=-1])` | 移除并返回指定位置的元素（默认最后一个） | `[1, 2, 3].pop()` → `3` |
# | `remove(obj)` | 移除列表中某个值的第一个匹配项 | `[1, 2, 1].remove(1)` → `[2, 1]` |
# | `reverse()` | 对列表元素进行原地反转 | `[1, 2, 3].reverse()` → `[3, 2, 1]` |
# | `sort(key=None, reverse=False)` | 对列表元素进行原地排序 | `[3, 1, 2].sort()` → `[1, 2, 3]` |
# | `clear()` | 清空列表中的所有元素 | `[1, 2, 3].clear()` → `[]` |
# | `copy()` | 返回列表的浅拷贝 | `[1, 2, 3].copy()` → `[1, 2, 3]` |

# %% [markdown]
# # 元组 ()
# - 元组写在小括号 () 里，元素之间用逗号隔开。
# - 元组的元素不能修改，但它可以包含可变的对象，比如 list 列表。
# - 组的不可变指的是元组所指向的内存中的内容不可变。重新赋值的元组 tup，绑定到新的对象了，不是修改了原来的对象。

# %%
my_tuple = ('abcd', 786, 2.23, 'runoob', 70.2)  # 避免用 tuple 作为变量名
tinytuple = (123, 'runoob')

tup1 = ()     # 创建空元组
tup2 = (20,)  # 只有一个元素，需要在元素后添加逗号

print(my_tuple)
print(my_tuple[0])
print(my_tuple[1:3])
print(my_tuple[2:])
print(tinytuple * 2)
print(my_tuple + tinytuple)

# %% [markdown]
# ## del删除整个元组

# %%
tup = ('Google', 'Runoob', 1997, 2000)

print (tup)
del tup
print ("删除后的元组 tup : ")
print (tup)

# %% [markdown]
# ## 元组内置函数

# %% [markdown]
# （Python 内置函数，传入元组作为参数）
#
# | 函数 | 描述 | 示例 |
# |---|---|---|
# | `len(tuple)` | 返回元组元素个数 | `len((1, 2, 3))` → `3` |
# | `max(tuple)` | 返回元组元素中的最大值 | `max((1, 2, 3))` → `3` |
# | `min(tuple)` | 返回元组元素中的最小值 | `min((1, 2, 3))` → `1` |
# | `tuple(seq)` | 将列表（或其他可迭代对象）转换为元组 | `tuple([1, 2, 3])` → `(1, 2, 3)` |

# %% [markdown]
# ## 元组实例方法

# %% [markdown]
# （通过元组对象调用。由于元组不可变，仅有两个方法）
#
# | 方法 | 描述 | 示例 |
# |---|---|---|
# | `count(obj)` | 统计某个元素在元组中出现的次数 | `(1, 2, 1).count(1)` → `2` |
# | `index(obj)` | 找出某个值第一个匹配项的索引位置 | `(1, 2, 3).index(2)` → `1` |

# %% [markdown]
# # 集合 {}

# %% [markdown]
# - 集合使用大括号 {} 表示，元素之间用逗号 , 分隔。也可以使用 set() 函数创建集合。创建一个空集合必须用 set()
# - 无序、可变的数据类型，用于存储唯一的元素。
# - 可以进行交集、并集、差集等常见的集合操作。

# %%
a = set('abracadabra')
b = set('alacazam')
print(a - b)       # a 和 b 的差集（在 a 中但不在 b 中）
print(a | b)       # a 和 b 的并集（在 a 或 b 中）
print(a & b)       # a 和 b 的交集（同时在 a 和 b 中）
print(a ^ b)       # a 和 b 的对称差集（在 a 或 b 中，但不同时存在）

# %% [markdown]
# ## 集合的增删改查

# %% [markdown]
# 添加元素：
# - s.add( x )：如果元素已存在，则不进行任何操作
# - s.update( x )：参数可以是列表，元组，字典等
#
# 移除元素：
# - s.remove( x )：如果元素不存在，则会发生错误
# - s.discard( x )：如果元素不存在，不会发生错误
# - s.pop() ：随机删除集合中的一个元素（pop 方法会对集合进行无序的排列，然后将这个无序排列集合的左面第一个元素进行删除）
# - s.clear()：清空集合
#
# 计算集合元素个数：len(s)
#
# 判断元素是否在集合中存在：x in s。

# %% [markdown]
# ## 集合内置方法

# %% [markdown]
# （通过集合对象直接调用，如 `{1, 2, 3}.add(4)`）
#
# | 方法 | 描述 | 示例 |
# |---|---|---|
# | `add(elem)` | 向集合中添加元素，若元素已存在则不进行任何操作 | `{1, 2}.add(3)` → `{1, 2, 3}` |
# | `clear()` | 移除集合中的所有元素 | `{1, 2, 3}.clear()` → `set()` |
# | `copy()` | 返回集合的浅拷贝 | `{1, 2}.copy()` → `{1, 2}` |
# | `difference(*others)` | 返回当前集合与其他集合的差集 | `{1, 2, 3}.difference({2, 4})` → `{1, 3}` |
# | `difference_update(*others)` | 移除当前集合中也存在于其他集合中的元素（原地修改） | `s = {1, 2, 3}; s.difference_update({2, 4})` → `s` 变为 `{1, 3}` |
# | `discard(elem)` | 移除指定元素，若元素不存在也不报错（推荐使用） | `{1, 2}.discard(2)` → `{1}` |
# | `intersection(*others)` | 返回当前集合与其他集合的交集 | `{1, 2, 3}.intersection({2, 3, 4})` → `{2, 3}` |
# | `intersection_update(*others)` | 用交集更新当前集合（原地修改） | `s = {1, 2, 3}; s.intersection_update({2, 3, 4})` → `s` 变为 `{2, 3}` |
# | `isdisjoint(other)` | 判断两个集合是否不相交（无相同元素），不相交返回 True | `{1, 2}.isdisjoint({3, 4})` → `True` |
# | `issubset(other)` | 判断当前集合是否为另一集合的子集 | `{1, 2}.issubset({1, 2, 3})` → `True` |
# | `issuperset(other)` | 判断当前集合是否为另一集合的超集 | `{1, 2, 3}.issuperset({1, 2})` → `True` |
# | `pop()` | 随机移除并返回一个元素，集合为空则报错 | `{1, 2, 3}.pop()` → 随机返回 1/2/3 |
# | `remove(elem)` | 移除指定元素，若元素不存在则报错 | `{1, 2}.remove(2)` → `{1}` |
# | `symmetric_difference(other)` | 返回两个集合的对称差集（仅在其中一个集合中出现的元素） | `{1, 2}.symmetric_difference({2, 3})` → `{1, 3}` |
# | `symmetric_difference_update(other)` | 用对称差集更新当前集合（原地修改） | `s = {1, 2}; s.symmetric_difference_update({2, 3})` → `s` 变为 `{1, 3}` |
# | `union(*others)` | 返回当前集合与其他集合的并集 | `{1, 2}.union({3, 4})` → `{1, 2, 3, 4}` |
# | `update(*others)` | 用其他集合（或可迭代对象）中的元素扩展当前集合 | `{1, 2}.update({3, 4})` → `{1, 2, 3, 4}` |
#
# > **注意：** `len()` 不是集合方法，而是 Python 内置函数，可传入集合作为参数：`len({1, 2, 3})` → `3`。

# %% [markdown]
# # 字典
# - 映射类型，用 {} 标识，它是一个 键(key) : 值(value) 的集合。键(key) 必须使用不可变类型，且在同一个字典中键必须是唯一的。
# - 构造函数 dict() 可以直接从键值对序列中构建字典。

# %%
my_dict = {}
my_dict['one'] = "1 - 菜鸟教程"
my_dict[2]     = "2 - 菜鸟工具"
tinydict = {'name': 'runoob', 'code': 1, 'site': 'www.runoob.com'}

print(my_dict['one'])       # 访问字典里的值
print(my_dict[2])
print(tinydict)             # 输出完整的字典
print(tinydict.keys())      # 输出所有键
print(tinydict.values())    # 输出所有值

print(dict([('Runoob', 1), ('Google', 2), ('Taobao', 3)]))
print(dict(Runoob=1, Google=2, Taobao=3))
{x: x**2 for x in (2, 4, 6)}  # 使用的是字典推导式

# %% [markdown]
# ## 修改字典

# %% [markdown]
# 向字典添加新内容的方法是增加新的键/值对，修改或删除已有键/值对如下实例:

# %%
tinydict = {'Name': 'Runoob', 'Age': 7, 'Class': 'First'}

tinydict['Age'] = 8               # 更新 Age
tinydict['School'] = "菜鸟教程"  # 添加信息

print ("tinydict['Age']: ", tinydict['Age'])
print ("tinydict['School']: ", tinydict['School'])

# %% [markdown]
# ## del删除字典元素

# %% [markdown]
# 能删单一的元素也能清空字典，清空只需一项操作。
#
# 显式删除一个字典用del命令，如下实例：

# %%
tinydict = {'Name': 'Runoob', 'Age': 7, 'Class': 'First'}

del tinydict['Name'] # 删除键 'Name'
tinydict.clear()     # 清空字典
del tinydict         # 删除字典，之后字典不再存在

print ("tinydict['Age']: ", tinydict['Age'])
print ("tinydict['School']: ", tinydict['School'])

# %% [markdown]
# ## 字典内置函数&方法

# %% [markdown]
# ### 适用于字典的内置函数
# （Python 内置函数，传入字典作为参数）
#
# | 函数 | 描述 | 示例 |
# |---|---|---|
# | `len(dict)` | 返回字典中键值对的数量 | `len({"a": 1, "b": 2})` → `2` |
# | `str(dict)` | 将字典转换为字符串表示 | `str({"a": 1})` → `"{'a': 1}"` |
# | `type(variable)` | 返回变量的类型 | `type({"a": 1})` → `<class 'dict'>` |
#
# ### 字典实例方法
# （通过字典对象调用，如 `{"a": 1}.keys()`）
#
# | 方法 | 描述 | 示例 |
# |---|---|---|
# | `keys()` | 返回一个包含字典所有键的视图 | `{"a": 1, "b": 2}.keys()` → `dict_keys(['a', 'b'])` |
# | `values()` | 返回一个包含字典所有值的视图 | `{"a": 1, "b": 2}.values()` → `dict_values([1, 2])` |
# | `items()` | 返回一个包含所有 (键, 值) 对的视图 | `{"a": 1}.items()` → `dict_items([('a', 1)])` |
# | `get(key[, default])` | 返回指定键的值，若键不存在则返回默认值（不报错） | `{"a": 1}.get("b", 0)` → `0` |
# | `setdefault(key[, default])` | 返回指定键的值，若键不存在则插入默认值并返回 | `{}.setdefault("a", 1)` → `1` |
# | `pop(key[, default])` | 移除指定键并返回其值，若键不存在且未设默认值则报错 | `{"a": 1, "b": 2}.pop("a")` → `1` |
# | `popitem()` | 移除并返回最后插入的键值对（LIFO 顺序） | `{"a": 1, "b": 2}.popitem()` → `('b', 2)` |
# | `update([other])` | 用另一个字典或可迭代对象的键值对更新当前字典 | `{"a": 1}.update({"b": 2})` → `{'a': 1, 'b': 2}` |
# | `clear()` | 清空字典中的所有键值对 | `{"a": 1}.clear()` → `{}` |
# | `copy()` | 返回字典的浅拷贝 | `{"a": 1}.copy()` → `{"a": 1}` |
# | `fromkeys(seq[, value])` | 使用序列中的元素作为键，创建新字典（类方法） | `dict.fromkeys(["a", "b"], 0)` → `{'a': 0, 'b': 0}` |

# %% [markdown]
# # 海象运算符:=
# 海象运算符（:=）允许在表达式内部进行赋值

# %%
# 传统写法
n = 10
if n > 5:
    print(n)

# 使用海象运算符
if (n := 10) > 5:
    print(n)

# %% [markdown]
# # 成员运算符 in/not in
# - in：如果在指定的序列中找到值返回 True，否则返回 False。
# - not in：如果在指定的序列中没有找到值返回 True，否则返回 False。

# %%
a = 10
b = 20
list = [1, 2, 3, 4, 5 ]

if ( a in list ):
   print ("1 - 变量 a 在给定的列表中 list 中")
else:
   print ("1 - 变量 a 不在给定的列表中 list 中")

if ( b not in list ):
   print ("2 - 变量 b 不在给定的列表中 list 中")
else:
   print ("2 - 变量 b 在给定的列表中 list 中")

# 修改变量 a 的值
a = 2
if ( a in list ):
   print ("3 - 变量 a 在给定的列表中 list 中")
else:
   print ("3 - 变量 a 不在给定的列表中 list 中")

# %% [markdown]
# # 随机数函数
# - -choice(seq)：从序列的元素中随机挑选一个元素，比如random.choice(range(10))，从0到9中随机挑选一个整数。
# - random()：随机生成下一个实数，它在[0,1)范围内。
# - seed([x])：改变随机数生成器的种子seed。不必特别去设定seed，Python会帮你选择seed。
# - shuffle(lst)：将序列的所有元素随机排序
# - uniform(x, y)：随机生成下一个实数，它在[x,y]范围内。

# %% [markdown]
# # 数学函数
# - abs(x)：返回数字的绝对值
# - ceil(x)：返回数字的上入整数。如math.ceil(4.1)
# - floor(x)：返回数字的下舍整数。如math.floor(4.9)
# - exp(x)：返回e的x次幂。如math.exp(1)
# - fabs(x)：以浮点数形式返回数字的绝对值。如math.fabs(-10)
# - max(x1, x2,...)：返回给定参数的最大值，参数可以为序列。
# - min(x1, x2,...)：返回给定参数的最小值，参数可以为序列。
# - modf(x)：返回x的整数部分与小数部分，两部分的数值符号与x相同，整数部分以浮点型表示。
# - pow(x, y)：x**y 运算后的值。
# - round(x [,n])：返回浮点数 x 的四舍五入值，如给出 n 值，则代表舍入到小数点后的位数。
# - sqrt(x)：返回数字x的平方根。

# %% [markdown]
# # if条件判断语句

# %% [markdown]
# ```python
# # if语句格式
# if condition_1:
#     statement_block_1
# elif condition_2:
#     statement_block_2
# else:
#     statement_block_3
# ```

# %%
age = int(input("请输入你家狗狗的年龄: "))
print("")
if age <= 0:
    print("你是在逗我吧!")
elif age == 1:
    print("相当于 14 岁的人。")
elif age == 2:
    print("相当于 22 岁的人。")
elif age > 2:
    human = 22 + (age -2)*5
    print("对应人类年龄: ", human)
input("点击 enter 键退出")

# %% [markdown]
# # match...case条件判断语句

# %% [markdown]
# match 后的对象会依次与 case 后的内容进行匹配，如果匹配成功，则执行匹配到的表达式，否则直接跳过，_ 可以匹配一切。

# %% [markdown]
# ```python
# # match语句格式
# match subject:
#     case <pattern_1>:
#         <action_1>
#     case <pattern_2>:
#         <action_2>
#     case <pattern_3>:
#         <action_3>
#     case _:  # 匹配任何值，类似于 default
#         <action_wildcard>
# ```

# %% [markdown]
# 一个 case 也可以设置多个匹配条件，条件使用 | 隔开
# ```python
# ...
#     case 401|403|404:
#         return "Not allowed"
# ```

# %% [markdown]
# # while循环语句

# %% [markdown]
# ```python
# # while循环语法格式
# while 判断条件(condition)：
#     执行语句(statements)……
# ```

# %% [markdown]
# ## while 循环使用 else 语句

# %% [markdown]
# 如果 while 后面的条件语句为 false 时，则执行 else 的语句块。
# ```python
# while <expr>:
#     <statement(s)>
# else:
#     <additional_statement(s)>
# ```

# %% [markdown]
# # range()函数

# %%
# range(num) 函数，它会生成数列
for i in range(5):
    print(i)

# 也可以指定区间的值
for i in range(5,9) :
    print(i)

# 也可以指定数字开始并指定不同的增量(甚至可以是负数，有时这也叫做'步长'):
for i in range(0, 10, 3):
    print(i)

# %%
# 可以结合 range() 和 len() 函数以遍历一个序列的索引
sites = ["Baidu", "Google","Runoob","Taobao"]
for i in range(len(sites)):
    print("当前访问的站点: ", sites[i])

# %%
# 可以使用 range() 函数来创建一个列表
print(list(range(5)))

# %% [markdown]
# # for循环语句

# %% [markdown]
# ```python
# # for循环语法格式
# for <variable> in <sequence>:
#     <statements>
# else:
#     <statements>

# %%
sites = ["Baidu", "Google","Runoob","Taobao"]
for site in sites:
    print(site)

# %%
word = 'runoob'
for letter in word:
    print(letter)

# %%
#  1 到 5 的所有数字：
for number in range(1, 6):
    print(number)

# %% [markdown]
# ## for...else 语句

# %% [markdown]
# for...else 语句用于在循环结束后执行一段代码。如果在循环过程中遇到了 break 语句，则会中断循环，此时不会执行 else 子句。
# ```python
# for item in iterable:
#     # 循环主体
# else:
#     # 循环结束后执行的代码

# %%
sites = ["Baidu", "Google","Runoob","Taobao"]
for site in sites:
    if site == "Runoob":
        print("菜鸟教程!")
        break
    print("循环数据 " + site)
else:
    print("没有循环数据!")
print("完成循环!")

# %% [markdown]
# # break 和 continue 语句及循环中的 else 子句

# %% [markdown]
# - break 语句可以跳出 for 和 while 的循环体。如果你从 for 或 while 循环中终止，任何对应的循环 else 块将不执行。
#
# - continue 语句被用来告诉 Python 跳过当前循环块中的剩余语句，然后继续进行下一轮循环
#
# - 循环语句可以有 else 子句，它在穷尽列表(以for循环)或条件变为 false (以while循环)导致循环终止时被执行，但循环被 break 终止时不执行。

# %%
for n in range(2, 10):
    for x in range(2, n):
        if n % x == 0:
            print(n, '等于', x, '*', n//x)
            break
    else:
        # 循环中没有找到元素
        print(n, ' 是质数')

# %% [markdown]
# # pass语句

# %% [markdown]
# pass 不做任何事情，一般用做占位语句

# %% [markdown]
# # 推导式

# %% [markdown]
# 一种独特的数据处理方式，可以从一个数据序列构建另一个新的数据序列的结构体。适用于生成列表、字典、集合和生成器

# %% [markdown]
# ## 列表推导式

# %% [markdown]
# [表达式 for 变量 in 列表]
#
#
# 或者
#
# [表达式 for 变量 in 列表 if 条件]
# 表达式：列表生成元素表达式，可以是有返回值的函数。
# for 变量 in 列表：迭代 列表 将 变量 传入到 表达式 中

# %%
names = ['Bob','Tom','alice','Jerry','Wendy','Smith']
new_names = [name.upper()for name in names if len(name)>3]
print(new_names)

multiples = [i for i in range(30) if i % 3 == 0]
print(multiples)

# %% [markdown]
# ## 字典推导式

# %% [markdown]
# { key_expr: value_expr for value in collection }
#
# 或
#
# { key_expr: value_expr for value in collection if condition }

# %%
# 将列表中各字符串值为键，各字符串的长度为值，组成键值对
listdemo = ['Google','Runoob', 'Taobao']
newdict = {key:len(key) for key in listdemo}
print(newdict)

# 提供三个数字，以三个数字为键，三个数字的平方为值来创建字典：
squaredict = {x: x**2 for x in (2, 4, 6)}
print(squaredict)

# %% [markdown]
# ## 集合推导式

# %% [markdown]
# { expression for item in Sequence }
#
# 或
#
# { expression for item in Sequence if conditional }

# %%
# 计算数字 1,2,3 的平方数：
squared = {x: x**2 for x in (1, 2, 3)}
print(squared)

# 判断不是 abc 的字母并输出：
a = {x for x in 'abracadabra' if x not in 'abc'}
print(a)

# %% [markdown]
# ## 元组推导式（生成器表达式）

# %% [markdown]
# 元组推导式可以利用 range 区间、元组、列表、字典和集合等数据类型，快速生成一个满足指定需求的元组。
#
# 元组推导式和列表推导式的用法也完全相同，只是元组推导式是用 () 圆括号将各部分括起来，而列表推导式用的是中括号 []，另外元组推导式返回的结果是一个生成器对象。
#
# 元组推导式基本格式：
#
# (expression for item in Sequence )
# 或
# (expression for item in Sequence if conditional )

# %%
# 生成一个包含数字 1~9 的元组：
a = (x for x in range(1,10))
print(a) # 生成器表达式返回一个生成器对象，而不是一个元组。

print(tuple(a)) # 使用 tuple() 函数，可以直接将生成器对象转换成元组

# %% [markdown]
# # 迭代器

# %% [markdown]
# - 访问集合元素的一种方式
# - 迭代器是一个可以记住遍历的位置的对象。
# - 迭代器对象从集合的第一个元素开始访问，直到所有的元素被访问完结束。迭代器只能往前不会后退。
# - 字符串，列表或元组对象都可用于创建迭代器：

# %%
# 迭代器有两个基本的方法：iter() 和 next()。
list=[1,2,3,4]
it = iter(list)    # 创建迭代器对象
print(next(it))    # 输出迭代器的下一个元素
print(next(it))

# %%
# 迭代器对象可以使用常规for语句进行遍历：
list=[1,2,3,4]
it = iter(list)    # 创建迭代器对象
for x in it:
    print (x, end=" ")


# 也可以使用 next() 函数：
import sys         # 引入 sys 模块
list=[1,2,3,4]
it = iter(list)    # 创建迭代器对象

while True:
    try:
        print (next(it))
    except StopIteration:  # StopIteration 异常用于标识迭代的完成
        sys.exit()

# %% [markdown]
# # 生成器

# %% [markdown]
# - 使用了 yield 的函数被称为生成器（generator）。
# - yield 是一个关键字，用于定义生成器函数，生成器函数是一种特殊的函数，可以在迭代过程中逐步产生值，而不是一次性返回所有结果。
# - 生成器是一个返回迭代器的函数，只能用于迭代操作，更简单点理解生成器就是一个迭代器。
# - 当在生成器函数中使用 yield 语句时，函数的执行将会暂停，并将 yield 后面的表达式作为当前迭代的值返回。
# - 次调用生成器的 next() 方法或使用 for 循环进行迭代时，函数会从上次暂停的地方继续执行，直到再次遇到 yield 语句。这样，生成器函数可以逐步产生值，而不需要一次性计算并返回所有结果。
# - 调用一个生成器函数，返回的是一个迭代器对象。

# %%
def countdown(n):
    while n > 0:
        yield n
        n -= 1

# 创建生成器对象
generator = countdown(5)

# 通过迭代生成器获取值
print(next(generator))  # 输出: 5
print(next(generator))  # 输出: 4
print(next(generator))  # 输出: 3

# 使用 for 循环迭代生成器
for value in generator:
    print(value)  # 输出: 2 1
    
'''
countdown 函数是一个生成器函数。它使用 yield 语句逐步产生从 n 到 1 的倒数数字。在每次调用 yield 语句时，函数会返回当前的倒数值，并在下一次调用时从上次暂停的地方继续执行。

通过创建生成器对象并使用 next() 函数或 for 循环迭代生成器，我们可以逐步获取生成器函数产生的值。在这个例子中，我们首先使用 next() 函数获取前三个倒数值，然后通过 for 循环获取剩下的两个倒数值。

生成器函数的优势是它们可以按需生成值，避免一次性生成大量数据并占用大量内存。此外，生成器还可以与其他迭代工具（如for循环）无缝配合使用，提供简洁和高效的迭代方式。
'''

# %%
# 使用 yield 实现斐波那契数列：
import sys

def fibonacci(n): # 生成器函数 - 斐波那契
    a, b, counter = 0, 1, 0
    while True:
        if (counter > n): 
            return
        yield a
        a, b = b, a + b
        counter += 1
f = fibonacci(10) # f 是一个迭代器，由生成器返回生成

while True:
    try:
        print (next(f), end=" ")
    except StopIteration:
        sys.exit()

# %% [markdown]
# # with 关键字

# %% [markdown]
# - with 是 Python 中的一个关键字，用于上下文管理协议。它简化了资源管理代码，特别是那些需要明确释放或清理的资源（如文件、网络连接、数据库连接等）。

# %%
file = open('example.txt', 'r')
try:
    content = file.read()
    # 处理文件内容
finally:
    file.close()

'''
这种写法存在几个问题：
容易忘记关闭资源：如果没有 try-finally 块，可能会忘记调用 close()
代码冗长：简单的文件操作需要多行代码
异常处理复杂：需要手动处理可能出现的异常


with 语句通过上下文管理协议（Context Management Protocol）解决了这些问题：
自动资源释放：确保资源在使用后被正确关闭
代码简洁：减少样板代码
异常安全：即使在代码块中发生异常，资源也会被正确释放
可读性强：明确标识资源的作用域
'''

# %% [markdown]
# with 语句的基本形式
# ```python
# with expression [as variable]:
#     # 代码块
# ```
#
# - expression 返回一个支持上下文管理协议的对象
# - as variable 是可选的，用于将表达式结果赋值给变量
# - 代码块执行完毕后，自动调用清理方法

# %%
with open('example.txt', 'r') as file:
    content = file.read()
    print(content)
# 文件已自动关闭

# %% [markdown]
# ## 实际应用场景

# %%
# 文件操作

# 同时打开多个文件
with open('input.txt', 'r') as infile, open('output.txt', 'w') as outfile:
    content = infile.read()
    outfile.write(content.upper())

# %%
# 数据库连接

import sqlite3

with sqlite3.connect('database.db') as conn:
    cursor = conn.cursor()
    cursor.execute('SELECT * FROM users')
    results = cursor.fetchall()
# 连接自动关闭

# %% [markdown]
# # 函数

# %% [markdown]
# 定义一个函数：
# - 函数代码块以 def 关键词开头，后接函数标识符名称和圆括号 ()。
# - 任何传入参数和自变量必须放在圆括号中间，圆括号之间可以用于定义参数。
# - 函数的第一行语句可以选择性地使用文档字符串—用于存放函数说明。
# - 函数内容以冒号 : 起始，并且缩进。
# - return [表达式] 结束函数，选择性地返回一个值给调用方，不带表达式的 return 相当于返回 None。
#
# ```python
# # 函数定义语法
# def 函数名（参数列表）:
#     函数体
# ```

# %% [markdown]
# ## 参数传递

# %% [markdown]
# ### 不定长参数

# %% [markdown]
# 需要一个函数能处理比当初声明时更多的参数。这些参数叫做不定长参数。
#
# 参数不同的是，声明时不会命名。基本语法如下：
# ```python
# def functionname([formal_args,] *var_args_tuple ):
#    "函数_文档字符串"
#    function_suite
#    return [expression]
# ```
# - 加了星号 * 的参数会以元组(tuple)的形式导入，存放所有未命名的变量参数。
# - 如果在函数调用时没有指定参数，它就是一个空元组。

# %%
# 可写函数说明
def printinfo( arg1, *vartuple ):
   "打印任何传入的参数"
   print ("输出: ")
   print (arg1)
   print (vartuple)

# 调用printinfo 函数
printinfo( 70, 60, 50 )

# %%
# 可写函数说明
def printinfo( arg1, *vartuple ):
   "打印任何传入的参数"
   print ("输出: ")
   print (arg1)
   for var in vartuple:
      print (var)
   return

# 调用printinfo 函数
printinfo( 10 )
printinfo( 70, 60, 50 )

# %% [markdown]
# 还有一种就是参数带两个星号 **基本语法如下：
# ```python
# def functionname([formal_args,] **var_args_dict ):
#    "函数_文档字符串"
#    function_suite
#    return [expression]
# ```
# - 加了两个星号 ** 的参数会以字典的形式导入。

# %%
# 可写函数说明
def printinfo( arg1, **vardict ):
   "打印任何传入的参数"
   print ("输出: ")
   print (arg1)
   print (vardict)

# 调用printinfo 函数
printinfo(1, a=2,b=3)

# %% [markdown]
# ### 强制关键词传参
# 声明函数时，参数中星号 * 可以单独出现。如果单独出现星号 *，则星号 * 后的参数必须用关键字传入：

# %%
def f(a,b,*,c):
    return a+b+c
print(f(1,2,c=3))

# %% [markdown]
# ### 强制位置传参
# 函数形参语法 / 用来指明函数形参必须使用指定位置参数，不能使用关键字参数的形式。

# %%
def f(a, b, /, c, d, *, e, f):
    print(a, b, c, d, e, f)
f(1, 2, c=3, d=4, e=5, f=6)
# b 不能使用关键字参数的形式
# e 必须使用关键字参数的形式

# %% [markdown]
# ## 匿名函数

# %% [markdown]
# 使用lambda 来创建匿名函数。
# - lambda 只是一个表达式，没有函数名称，只能通过赋值给变量或作为参数传递给其他函数来使用。
# - lambda 函数拥有自己的命名空间，且不能访问自己参数列表之外或全局命名空间里的参数。
#
# lambda 函数的语法只包含一个语句，如下：
# ```python
# lambda [arg1 [,arg2,.....argn]] : expression
# # arg为参数，包含零个或多个参数
# ```

# %%
x = lambda a : a + 10
print(x(5))

# 可写函数说明
sum = lambda arg1, arg2: arg1 + arg2
# 调用sum函数
print ("相加后的值为 : ", sum( 10, 20 ))
print ("相加后的值为 : ", sum( 20, 20 ))

# %% [markdown]
# 我们可以将匿名函数封装在一个函数内，这样可以使用同样的代码来创建多个匿名函数。

# %%
def myfunc(n):
  return lambda a : a * n

mydoubler = myfunc(2)
mytripler = myfunc(3)

print(mydoubler(11))
print(mytripler(11))

# %% [markdown]
# lambda 函数通常与内置函数如 map()、filter() 和 reduce() 一起使用，以便在集合上执行操作

# %%
# map() 函数会根据提供的函数对指定序列做映射。
numbers = [1, 2, 3, 4, 5]
squared = list(map(lambda x: x**2, numbers))
print(squared)  # 输出: [1, 4, 9, 16, 25]


# 与 filter() 一起，筛选偶数，filter() 函数会根据提供的函数对指定序列进行筛选：
numbers = [1, 2, 3, 4, 5, 6, 7, 8]
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
print(even_numbers)  # 输出：[2, 4, 6, 8]


# reduce() 函数会对参数序列中元素进行累积。函数必须接收两个参数，reduce() 会对序列中的元素进行累积计算。
from functools import reduce

numbers = [1, 2, 3, 4, 5]
# 使用 reduce() 和 lambda 函数计算乘积
product = reduce(lambda x, y: x * y, numbers) # 计算 1*2*3*4*5
print(product)  # 输出：120
'''reduce() 函数的工作原理如下：
第一步:  1 * 2 = 2      (拿前两个元素，算出 2)
第二步:  2 * 3 = 6      (用上一步的结果和下一个元素，算出 6)
第三步:  6 * 4 = 24
第四步:  24 * 5 = 120   (最终结果)
reduce() 函数会将前两个元素进行计算，然后将结果与下一个元素进行计算，依此类推，直到序列中所有元素都被处理完毕，最终得到一个结果。
    常见用途：求乘积、求最大值、把多个列表拼成一个、多层字典取值等。
'''

# %% [markdown]
# # 装饰器

# %% [markdown]
# - 用于在不修改原函数代码的前提下，动态扩展函数或类的功能。
# - 本质上，装饰器是一个函数：它接收一个函数作为参数，并返回一个新的函数（通常是对原函数的增强版本）。
# - 装饰器通过 @decorator_name 语法应用在函数或方法定义之前。Python 还提供了一些内置装饰器，例如 @staticmethod 和 @classmethod。
# - 常见应用场景：
# 日志记录：记录函数调用信息、参数和返回值。
# 性能统计：统计函数执行时间。
# 权限控制：限制函数访问权限。
# 缓存：缓存函数结果，提高性能。

# %% [markdown]
# ## 前置知识：函数也是对象

# %% [markdown]
# - 函数可以赋值给变量
# - 函数可以作为参数传递给另一个函数
# - 函数可以作为另一个函数的返回值
# - 函数可以定义在另一个函数内部（嵌套函数 / 闭包）

# %%
def greet(name):
    return f"Hello, {name}"

# 函数赋值给变量
say_hello = greet
print(say_hello("World"))  # Hello, World

# 函数作为参数传递
def execute(func, arg):
    return func(arg)

print(execute(greet, "Alice"))  # Hello, Alice

# %% [markdown]
# ##  装饰器核心原理：手工实现

# %%
def add(a, b):
    return a + b

def logging_decorate(func):
    def wrapper(a, b):
        print(f"Calling {func.__name__} with {a}, {b}")
        result = func(a, b)
        print(f"{func.__name__} returned {result}")
        return result
    return wrapper

# 手动装饰
add = logging_decorate(add)
add(3, 5)

# %% [markdown]
# ## @ 语法糖
# Python 允许用 @装饰器名 的方式，在函数定义上方直接应用装饰器，避免手动赋值。

# %%
def logger(func):
    def wrapper(*args, **kwargs):
        print(f"Calling {func.__name__}")
        return func(*args, **kwargs)
    return wrapper

@logger
def say(message):
    print(message)

say("Hello decorator!")

# %% [markdown]
# ## 装饰任意参数的函数
# - 为了让装饰器能适应不同签名的函数，内部包装函数应统一使用 *args 和 **kwargs 来收集位置参数和关键字参数，并原样传递给原函数。
# - 这样一来，同一个装饰器可以用于任何函数。

# %%
def tracer(func):
    def wrapper(*args, **kwargs):
        print(f"Calling {func.__name__} with args={args}, kwargs={kwargs}")
        result = func(*args, **kwargs)
        print(f"Returned: {result}")
        return result
    return wrapper

@tracer
def multiply(x, y):
    return x * y

@tracer
def greet(name, punctuation="!"):
    return f"Hello{punctuation} {name}"

multiply(3, 7)
greet("Bob", punctuation="...")

# %% [markdown]
# 装饰器通过 @ 语法糖应用在函数定义前：
# ```python
# @time_logger
# def target_function():
#     pass
# ```
# 等价于：
# ```python
# def target_function():
#     pass
#
# target_function = time_logger(target_function)
# ```
#
# 这种机制使我们可以在**不修改原函数的情况下，统一添加功能（如日志、权限等）**。

# %%
def my_decorator(func):
    def wrapper():
        print("函数执行前")
        func()
        print("函数执行后")
    return wrapper

@my_decorator
def say_hello():
    print("Hello!")

say_hello()

# %% [markdown]
# ## 带参数的装饰器

# %% [markdown]
# 如果原函数有参数，需要在 wrapper 中使用 *args, **kwargs。
#
# 使用 *args, **kwargs 可以兼容任意参数函数。|

# %%
def my_decorator(func):
    def wrapper(*args, **kwargs):
        print("执行前")
        func(*args, **kwargs)
        print("执行后")
    return wrapper

@my_decorator
def greet(name):
    print(f"Hello, {name}!")

greet("Alice")

# %%
# 带参数的装饰器（进阶）
def repeat(num_times):
    def decorator(func):
        def wrapper(*args, **kwargs):
            for _ in range(num_times):
                func(*args, **kwargs)
        return wrapper
    return decorator

@repeat(3)
def say_hello():
    print("Hello!")

say_hello()
